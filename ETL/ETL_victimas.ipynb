# %%
import pandas as pd

archivo = pd.ExcelFile('../archivos/originales/homicidios.xlsx')

def CalcularNulos(df):
    for columna in df:
        nulos = 100*(df[columna].isnull().sum()/df.shape[0])
        porcentaje = "{:.1f}".format(nulos)
        print("el porcentaje de datos nulos en la columna ",df[columna].name," es del ",porcentaje,"%")

    print('-------------------------------------------------------------------------------------------')

# %% [markdown]
# #########################################################################################################
# ************************************************************************
#
# **ETL Victimas**

# %%
df_victimas = pd.read_excel(archivo,sheet_name="VICTIMAS")

# %%
df_victimas.info
# Out:
# <bound method DataFrame.info of       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0    2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021  12  30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021  12  15             CONDUCTOR    AUTO
#
#           SEXO EDAD  FECHA_FALLECIMIENTO
# 0    MASCULINO   19  2016-01-01 00:00:00
# ...

# %%
df_victimas.describe(include='all')
# Out:
#          ID_hecho                          FECHA         AAAA          MM  \
# count         717                            717   717.000000  717.000000
# unique        696                            NaN          NaN         NaN
# top     2017-0035                            NaN          NaN         NaN
# freq            3                            NaN          NaN         NaN
# mean          NaN  2018-09-09 01:36:24.100418304  2018.174338    6.688982
# min           NaN            2016-01-01 00:00:00  2016.000000    1.000000
# 25%           NaN            2017-04-01 00:00:00  2017.000000    4.000000
# 50%           NaN            2018-07-07 00:00:00  2018.000000    7.000000
# 75%           NaN            2019-12-18 00:00:00  2019.000000   10.000000
# max           NaN            2021-12-30 00:00:00  2021.000000   12.000000
# std           NaN                            NaN     1.672655    3.575140
#
#                 DD        ROL VICTIMA       SEXO EDAD FECHA_FALLECIMIENTO
# ...

# %%
df_victimas.replace('SD',None)
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0    2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021  12  30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021  12  15             CONDUCTOR    AUTO
#
#           SEXO EDAD  FECHA_FALLECIMIENTO
# 0    MASCULINO   19  2016-01-01 00:00:00
# 1    MASCULINO   70  2016-01-02 00:00:00
# ...

# %%
CalcularNulos(df_victimas)
# Out:
# el porcentaje de datos nulos en la columna  ID_hecho  es del  0.0 %
# el porcentaje de datos nulos en la columna  FECHA  es del  0.0 %
# el porcentaje de datos nulos en la columna  AAAA  es del  0.0 %
# el porcentaje de datos nulos en la columna  MM  es del  0.0 %
# el porcentaje de datos nulos en la columna  DD  es del  0.0 %
# el porcentaje de datos nulos en la columna  ROL  es del  0.0 %
# el porcentaje de datos nulos en la columna  VICTIMA  es del  0.0 %
# el porcentaje de datos nulos en la columna  SEXO  es del  0.0 %
# el porcentaje de datos nulos en la columna  EDAD  es del  0.0 %
# el porcentaje de datos nulos en la columna  FECHA_FALLECIMIENTO  es del  0.0 %
# -------------------------------------------------------------------------------------------

# %%
duplicados = df_victimas[df_victimas['AAAA'].duplicated()]

# %%
df_victimas['SEXO'].value_counts()
# Out:
# SEXO
# MASCULINO    545
# FEMENINO     166
# SD             6
# Name: count, dtype: int64

# %%
df_victimas.head(40)
# Out:
#      ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0   2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1   2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2   2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3   2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4   2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# 5   2016-0008 2016-01-24  2016   1  24             CONDUCTOR    MOTO
# 6   2016-0009 2016-01-24  2016   1  24  PASAJERO_ACOMPAÑANTE    MOTO
# 7   2016-0010 2016-01-29  2016   1  29             CONDUCTOR    MOTO
# 8   2016-0012 2016-02-08  2016   2   8             CONDUCTOR    MOTO
# 9   2016-0013 2016-02-10  2016   2  10                PEATON  PEATON
# 10  2016-0015 2016-02-14  2016   2  14                PEATON  PEATON
# 11  2016-0016 2016-02-14  2016   2  14  PASAJERO_ACOMPAÑANTE    MOTO
# 12  2016-0017 2016-02-15  2016   2  15                PEATON  PEATON
# ...
